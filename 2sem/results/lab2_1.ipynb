# %%
from google.colab import auth
auth.authenticate_user()

# %%
from PIL import Image as pim
import numpy as np

# %%
def moveToSemitone(image):
    imageData = image.load()
    resultImage = pim.new('L',image.size)
    newImageData = resultImage.load()
    for x in range(image.size[0]):
      for y in range(image.size[1]):
        newImageData[x,y] = int(0.3*imageData[x,y][0] + 0.59 * imageData[x,y][1] + 0.11 * imageData[x,y][2])
    return resultImage

# %%
input_image = pim.open("im1.png")
output_image = moveToSemitone(input_image)
output_image.show()

# %%
input_image
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
output_image
# Out:
# <PIL.Image.Image image mode=L size=1694x929>
